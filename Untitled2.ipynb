# %%
from IPython.display import FileLink

FileLink(r'data/Health_Prediction_Models_Presentation.pptx')
# Out:
# D:\DSML\project1\data\Health_Prediction_Models_Presentation.pptx

# %%
# Save the presentation again and ensure the path is correct
presentation_path = "/mnt/data/Health_Prediction_Models_Presentation_v2.pptx"
prs.save(presentation_path)

presentation_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Save the presentation again and ensure the path is correct
#       2 presentation_path = "/mnt/data/Health_Prediction_Models_Presentation_v2.pptx"
# ----> 3 prs.save(presentation_path)
#       5 presentation_path
#
# NameError: name 'prs' is not defined

# %%
from pptx import Presentation
from pptx.util import Inches

# Create a presentation object
prs = Presentation()

# Slide 1: Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[0])
title = slide_1.shapes.title
subtitle = slide_1.placeholders[1]

title.text = "Health Prediction Models"
subtitle.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"

# Slide 2: Introduction
slide_2 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_2.shapes.title
content = slide_2.shapes.placeholders[1].text_frame

title.text = "Introduction"
content.text = "This project involves the development of machine learning models to predict health conditions including Parkinson's Disease, Diabetes, and Heart Disease. The models are deployed using Streamlit, a powerful framework for building web applications in Python."

# Slide 3: Parkinson's Disease Prediction Model
slide_3 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_3.shapes.title
content = slide_3.shapes.placeholders[1].text_frame

title.text = "Parkinson's Disease Prediction Model"
content.text = "• Parkinson's Disease is a neurodegenerative disorder.\n• Features used include MDVP metrics, shimmer, jitter, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."

# Slide 4: Diabetes Prediction Model
slide_4 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_4.shapes.title
content = slide_4.shapes.placeholders[1].text_frame

title.text = "Diabetes Prediction Model"
content.text = "• Diabetes is a chronic condition that affects the body's ability to process blood glucose.\n• Features include Pregnancies, Glucose, BMI, Age, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."

# Slide 5: Heart Disease Prediction Model
slide_5 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_5.shapes.title
content = slide_5.shapes.placeholders[1].text_frame

title.text = "Heart Disease Prediction Model"
content.text = "• Heart Disease is a range of conditions that affect the heart.\n• Features include Age, Sex, Cholesterol, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."

# Slide 6: Implementation in Streamlit
slide_6 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_6.shapes.title
content = slide_6.shapes.placeholders[1].text_frame

title.text = "Implementation in Streamlit"
content.text = "• The web application is built using Streamlit.\n• The models are integrated into a single interface.\n• Custom styling is applied for better user experience.\n• The app includes navigation and prediction buttons."

# Slide 7: Results & Accuracy
slide_7 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_7.shapes.title
content = slide_7.shapes.placeholders[1].text_frame

title.text = "Results & Accuracy"
content.text = "• Each model's accuracy is evaluated.\n• The predictions are presented to the user in a clear manner.\n• The models show promising results for health prediction."

# Slide 8: Conclusion
slide_8 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_8.shapes.title
content = slide_8.shapes.placeholders[1].text_frame

title.text = "Conclusion"
content.text = "• This project successfully developed and deployed models for predicting Parkinson's Disease, Diabetes, and Heart Disease.\n• The web application is user-friendly and provides accurate predictions.\n• Future work could include adding more models and enhancing the UI."

# Slide 9: Q&A
slide_9 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_9.shapes.title
content = slide_9.shapes.placeholders[1].text_frame

title.text = "Q&A"
content.text = "Any questions?"

# Save the presentation
prs.save("Health_Prediction_Models_Presentation.pptx")

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN
from pptx.dml.color import RGBColor
from pptx.enum.shapes import MSO_SHAPE
from pptx.oxml.ns import nsdecls
from pptx.oxml import parse_xml

# Create a presentation object
prs = Presentation()

# Define a function to apply styling to text
def apply_text_style(text_frame, font_size=24, font_color=RGBColor(0, 0, 0)):
    for paragraph in text_frame.paragraphs:
        for run in paragraph.runs:
            run.font.size = Pt(font_size)
            run.font.color.rgb = font_color

# Slide 1: Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
title_shape = slide_1.shapes.title
title_shape.text = "Health Prediction Models"
apply_text_style(title_shape.text_frame, font_size=36, font_color=RGBColor(0, 102, 204))

subtitle_shape = slide_1.placeholders[1]
subtitle_shape.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"
apply_text_style(subtitle_shape.text_frame, font_size=18)

# Slide 2: Introduction
slide_2 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_2.shapes.title
content = slide_2.shapes.placeholders[1].text_frame

title.text = "Introduction"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "This project involves the development of machine learning models to predict health conditions including Parkinson's Disease, Diabetes, and Heart Disease. The models are deployed using Streamlit, a powerful framework for building web applications in Python."
apply_text_style(content, font_size=20)

# Slide 3: Parkinson's Disease Prediction Model
slide_3 = prs.slides.add_slide(prs.slide_layouts[6])
title = slide_3.shapes.title
title.text = "Parkinson's Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Parkinson's model
parkinson_img_path = "path_to_your_parkinsons_image.png"  # Replace with your image path
slide_3.shapes.add_picture(parkinson_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_3.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Parkinson's Disease is a neurodegenerative disorder.\n• Features used include MDVP metrics, shimmer, jitter, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 4: Diabetes Prediction Model
slide_4 = prs.slides.add_slide(prs.slide_layouts[6])
title = slide_4.shapes.title
title.text = "Diabetes Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Diabetes model
diabetes_img_path = "path_to_your_diabetes_image.png"  # Replace with your image path
slide_4.shapes.add_picture(diabetes_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_4.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Diabetes is a chronic condition that affects the body's ability to process blood glucose.\n• Features include Pregnancies, Glucose, BMI, Age, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 5: Heart Disease Prediction Model
slide_5 = prs.slides.add_slide(prs.slide_layouts[6])
title = slide_5.shapes.title
title.text = "Heart Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Heart Disease model
heart_img_path = "path_to_your_heart_image.png"  # Replace with your image path
slide_5.shapes.add_picture(heart_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_5.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Heart Disease is a range of conditions that affect the heart.\n• Features include Age, Sex, Cholesterol, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 6: Implementation in Streamlit
slide_6 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_6.shapes.title
content = slide_6.shapes.placeholders[1].text_frame

title.text = "Implementation in Streamlit"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "• The web application is built using Streamlit.\n• The models are integrated into a single interface.\n• Custom styling is applied for better user experience.\n• The app includes navigation and prediction buttons."
apply_text_style(content, font_size=20)

# Slide 7: Results & Accuracy
slide_7 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_7.shapes.title
content = slide_7.shapes.placeholders[1].text_frame

title.text = "Results & Accuracy"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "• Each model's accuracy is evaluated.\n• The predictions are presented to the user in a clear manner.\n• The models show promising results for health prediction."
apply_text_style(content, font_size=20)

# Slide 8: Conclusion
slide_8 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_8.shapes.title
content = slide_8.shapes.placeholders[1].text_frame

title.text = "Conclusion"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "• This project successfully developed and deployed models for predicting Parkinson's Disease, Diabetes, and Heart Disease.\n• The web application is user-friendly and provides accurate predictions.\n• Future work could include adding more models and enhancing the UI."
apply_text_style(content, font_size=20)

# Slide 9: Q&A
slide_9 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_9.shapes.title
content = slide_9.shapes.placeholders[1].text_frame

title.text = "Q&A"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "Any questions?"
apply_text_style(content, font_size=20)

# Save the presentation
prs.save("Styled_Health_Prediction_Models_Presentation.pptx")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 25
#      22 title_shape.text = "Health Prediction Models"
#      23 apply_text_style(title_shape.text_frame, font_size=36, font_color=RGBColor(0, 102, 204))
# ---> 25 subtitle_shape = slide_1.placeholders[1]
#      26 subtitle_shape.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"
#      27 apply_text_style(subtitle_shape.text_frame, font_size=18)
#
# File ~\miniconda3\Lib\site-packages\pptx\shapes\shapetree.py:791, in SlidePlaceholders.__getitem__(self, idx)
#     789     if e.ph_idx == idx:
#     790         return SlideShapeFactory(e, self)
# --> 791 raise KeyError("no placeholder on this slide with idx == %d" % idx)
#
# KeyError: 'no placeholder on this slide with idx == 1'

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN
from pptx.dml.color import RGBColor
from pptx.enum.shapes import MSO_SHAPE
from pptx.oxml.ns import nsdecls
from pptx.oxml import parse_xml

# Create a presentation object
prs = Presentation()

# Define a function to apply styling to text
def apply_text_style(text_frame, font_size=24, font_color=RGBColor(0, 0, 0)):
    for paragraph in text_frame.paragraphs:
        for run in paragraph.runs:
            run.font.size = Pt(font_size)
            run.font.color.rgb = font_color

# Slide 1: Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
title_shape = slide_1.shapes.title
title_shape.text = "Health Prediction Models"
apply_text_style(title_shape.text_frame, font_size=36, font_color=RGBColor(0, 102, 204))

subtitle_shape = slide_1.placeholders[1]
subtitle_shape.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"
apply_text_style(subtitle_shape.text_frame, font_size=18)

# Slide 2: Introduction
slide_2 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_2.shapes.title
content = slide_2.shapes.placeholders[1].text_frame

title.text = "Introduction"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "This project involves the development of machine learning models to predict health conditions including Parkinson's Disease, Diabetes, and Heart Disease. The models are deployed using Streamlit, a powerful framework for building web applications in Python."
apply_text_style(content, font_size=20)

# Slide 3: Parkinson's Disease Prediction Model
slide_3 = prs.slides.add_slide(prs.slide_layouts[6])
title = slide_3.shapes.title
title.text = "Parkinson's Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Parkinson's model
parkinson_img_path = "path_to_your_parkinsons_image.png"  # Replace with your image path
slide_3.shapes.add_picture(parkinson_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_3.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Parkinson's Disease is a neurodegenerative disorder.\n• Features used include MDVP metrics, shimmer, jitter, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 4: Diabetes Prediction Model
slide_4 = prs.slides.add_slide(prs.slide_layouts[6])
title = slide_4.shapes.title
title.text = "Diabetes Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Diabetes model
diabetes_img_path = "path_to_your_diabetes_image.png"  # Replace with your image path
slide_4.shapes.add_picture(diabetes_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_4.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Diabetes is a chronic condition that affects the body's ability to process blood glucose.\n• Features include Pregnancies, Glucose, BMI, Age, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 5: Heart Disease Prediction Model
slide_5 = prs.slides.add_slide(prs.slide_layouts[6])
title = slide_5.shapes.title
title.text = "Heart Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Heart Disease model
heart_img_path = "path_to_your_heart_image.png"  # Replace with your image path
slide_5.shapes.add_picture(heart_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_5.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Heart Disease is a range of conditions that affect the heart.\n• Features include Age, Sex, Cholesterol, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 6: Implementation in Streamlit
slide_6 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_6.shapes.title
content = slide_6.shapes.placeholders[1].text_frame

title.text = "Implementation in Streamlit"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "• The web application is built using Streamlit.\n• The models are integrated into a single interface.\n• Custom styling is applied for better user experience.\n• The app includes navigation and prediction buttons."
apply_text_style(content, font_size=20)

# Slide 7: Results & Accuracy
slide_7 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_7.shapes.title
content = slide_7.shapes.placeholders[1].text_frame

title.text = "Results & Accuracy"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "• Each model's accuracy is evaluated.\n• The predictions are presented to the user in a clear manner.\n• The models show promising results for health prediction."
apply_text_style(content, font_size=20)

# Slide 8: Conclusion
slide_8 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_8.shapes.title
content = slide_8.shapes.placeholders[1].text_frame

title.text = "Conclusion"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "• This project successfully developed and deployed models for predicting Parkinson's Disease, Diabetes, and Heart Disease.\n• The web application is user-friendly and provides accurate predictions.\n• Future work could include adding more models and enhancing the UI."
apply_text_style(content, font_size=20)

# Slide 9: Q&A
slide_9 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_9.shapes.title
content = slide_9.shapes.placeholders[1].text_frame

title.text = "Q&A"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content.text = "Any questions?"
apply_text_style(content, font_size=20)

# Save the presentation
prs.save("Styled_Health_Prediction_Models_Presentation.pptx")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 25
#      22 title_shape.text = "Health Prediction Models"
#      23 apply_text_style(title_shape.text_frame, font_size=36, font_color=RGBColor(0, 102, 204))
# ---> 25 subtitle_shape = slide_1.placeholders[1]
#      26 subtitle_shape.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"
#      27 apply_text_style(subtitle_shape.text_frame, font_size=18)
#
# File ~\miniconda3\Lib\site-packages\pptx\shapes\shapetree.py:791, in SlidePlaceholders.__getitem__(self, idx)
#     789     if e.ph_idx == idx:
#     790         return SlideShapeFactory(e, self)
# --> 791 raise KeyError("no placeholder on this slide with idx == %d" % idx)
#
# KeyError: 'no placeholder on this slide with idx == 1'

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor

# Create a presentation object
prs = Presentation()

# Define a function to apply styling to text
def apply_text_style(text_frame, font_size=24, font_color=RGBColor(0, 0, 0)):
    for paragraph in text_frame.paragraphs:
        for run in paragraph.runs:
            run.font.size = Pt(font_size)
            run.font.color.rgb = font_color

# Slide 1: Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
title_shape = slide_1.shapes.title
title_shape.text = "Health Prediction Models"
apply_text_style(title_shape.text_frame, font_size=36, font_color=RGBColor(0, 102, 204))

subtitle_shape = slide_1.shapes.add_textbox(Inches(1), Inches(2), Inches(8), Inches(2))
subtitle_tf = subtitle_shape.text_frame
subtitle_tf.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"
apply_text_style(subtitle_tf, font_size=18)

# Slide 2: Introduction
slide_2 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_2.shapes.title
title.text = "Introduction"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_2.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8), Inches(4))
content = content_box.text_frame
content.text = "This project involves the development of machine learning models to predict health conditions including Parkinson's Disease, Diabetes, and Heart Disease. The models are deployed using Streamlit, a powerful framework for building web applications in Python."
apply_text_style(content, font_size=20)

# Slide 3: Parkinson's Disease Prediction Model
slide_3 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_3.shapes.title
title.text = "Parkinson's Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Parkinson's model
parkinson_img_path = "p.png"  # Replace with your image path
slide_3.shapes.add_picture(parkinson_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_3.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Parkinson's Disease is a neurodegenerative disorder.\n• Features used include MDVP metrics, shimmer, jitter, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 4: Diabetes Prediction Model
slide_4 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_4.shapes.title
title.text = "Diabetes Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Diabetes model
diabetes_img_path = "d.png"  # Replace with your image path
slide_4.shapes.add_picture(diabetes_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_4.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Diabetes is a chronic condition that affects the body's ability to process blood glucose.\n• Features include Pregnancies, Glucose, BMI, Age, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 5: Heart Disease Prediction Model
slide_5 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_5.shapes.title
title.text = "Heart Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Heart Disease model
heart_img_path = "h.png"  # Replace with your image path
slide_5.shapes.add_picture(heart_img_path, Inches(1), Inches(1.5), height=Inches(4))

content_box = slide_5.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Heart Disease is a range of conditions that affect the heart.\n• Features include Age, Sex, Cholesterol, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 6: Implementation in Streamlit
slide_6 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_6.shapes.title
title.text = "Implementation in Streamlit"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_6.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• The web application is built using Streamlit.\n• The models are integrated into a single interface.\n• Custom styling is applied for better user experience.\n• The app includes navigation and prediction buttons."
apply_text_style(text_frame, font_size=20)

# Slide 7: Results & Accuracy
slide_7 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_7.shapes.title
title.text = "Results & Accuracy"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_7.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Each model's accuracy is evaluated.\n• The predictions are presented to the user in a clear manner.\n• The models show promising results for health prediction."
apply_text_style(text_frame, font_size=20)

# Slide 8: Conclusion
slide_8 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_8.shapes.title
title.text = "Conclusion"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_8.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• This project successfully developed and deployed models for predicting Parkinson's Disease, Diabetes, and Heart Disease.\n• The web application is user-friendly and provides accurate predictions.\n• Future work could include adding more models and enhancing the UI."
apply_text_style(text_frame, font_size=20)

# Slide 9: Q&A
slide_9 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_9.shapes.title
title.text = "Q&A"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_9.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "Any questions?"
apply_text_style(text_frame, font_size=20)

# Save the presentation
prs.save("Styled_Health_Prediction_Models_Presentation_v2.pptx")

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor

# Create a presentation object
prs = Presentation()

# Define a function to apply styling to text
def apply_text_style(text_frame, font_size=24, font_color=RGBColor(0, 0, 0)):
    for paragraph in text_frame.paragraphs:
        for run in paragraph.runs:
            run.font.size = Pt(font_size)
            run.font.color.rgb = font_color

# Slide 1: Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[5])
title_shape = slide_1.shapes.title
title_shape.text = "Health Prediction Models"
apply_text_style(title_shape.text_frame, font_size=36, font_color=RGBColor(0, 102, 204))

subtitle_shape = slide_1.shapes.add_textbox(Inches(1), Inches(2.5), Inches(8), Inches(2))
subtitle_tf = subtitle_shape.text_frame
subtitle_tf.text = "Parkinson's, Diabetes, and Heart Disease Prediction using Machine Learning\nYour Name\nDate"
apply_text_style(subtitle_tf, font_size=18)

# Slide 2: Introduction
slide_2 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_2.shapes.title
title.text = "Introduction"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_2.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8.5), Inches(5))
content = content_box.text_frame
content.text = "This project involves the development of machine learning models to predict health conditions including Parkinson's Disease, Diabetes, and Heart Disease. The models are deployed using Streamlit, a powerful framework for building web applications in Python."
apply_text_style(content, font_size=20)

# Slide 3: Parkinson's Disease Prediction Model
slide_3 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_3.shapes.title
title.text = "Parkinson's Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Parkinson's model
parkinson_img_path = "p.png"  # Replace with your image path
slide_3.shapes.add_picture(parkinson_img_path, Inches(1), Inches(1.5), height=Inches(3.5))

content_box = slide_3.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(3.5))
text_frame = content_box.text_frame
text_frame.text = "• Parkinson's Disease is a neurodegenerative disorder.\n• Features used include MDVP metrics, shimmer, jitter, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 4: Diabetes Prediction Model
slide_4 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_4.shapes.title
title.text = "Diabetes Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Diabetes model
diabetes_img_path = "d.png"  # Replace with your image path
slide_4.shapes.add_picture(diabetes_img_path, Inches(1), Inches(1.5), height=Inches(3.5))

content_box = slide_4.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(3.5))
text_frame = content_box.text_frame
text_frame.text = "• Diabetes is a chronic condition that affects the body's ability to process blood glucose.\n• Features include Pregnancies, Glucose, BMI, Age, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 5: Heart Disease Prediction Model
slide_5 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_5.shapes.title
title.text = "Heart Disease Prediction Model"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

# Insert a placeholder image for the Heart Disease model
heart_img_path = "h.png"  # Replace with your image path
slide_5.shapes.add_picture(heart_img_path, Inches(1), Inches(1.5), height=Inches(3.5))

content_box = slide_5.shapes.add_textbox(Inches(5.5), Inches(1.5), Inches(4), Inches(3.5))
text_frame = content_box.text_frame
text_frame.text = "• Heart Disease is a range of conditions that affect the heart.\n• Features include Age, Sex, Cholesterol, etc.\n• The model is implemented using Logistic Regression.\n• The prediction interface is integrated with Streamlit."
apply_text_style(text_frame, font_size=20)

# Slide 6: Implementation in Streamlit
slide_6 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_6.shapes.title
title.text = "Implementation in Streamlit"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_6.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8.5), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• The web application is built using Streamlit.\n• The models are integrated into a single interface.\n• Custom styling is applied for better user experience.\n• The app includes navigation and prediction buttons."
apply_text_style(text_frame, font_size=20)

# Slide 7: Results & Accuracy
slide_7 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_7.shapes.title
title.text = "Results & Accuracy"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_7.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8.5), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• Each model's accuracy is evaluated.\n• The predictions are presented to the user in a clear manner.\n• The models show promising results for health prediction."
apply_text_style(text_frame, font_size=20)

# Slide 8: Conclusion
slide_8 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_8.shapes.title
title.text = "Conclusion"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_8.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8.5), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "• This project successfully developed and deployed models for predicting Parkinson's Disease, Diabetes, and Heart Disease.\n• The web application is user-friendly and provides accurate predictions.\n• Future work could include adding more models and enhancing the UI."
apply_text_style(text_frame, font_size=20)

# Slide 9: Q&A
slide_9 = prs.slides.add_slide(prs.slide_layouts[5])
title = slide_9.shapes.title
title.text = "Q&A"
apply_text_style(title.text_frame, font_size=30, font_color=RGBColor(255, 69, 0))

content_box = slide_9.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8.5), Inches(4))
text_frame = content_box.text_frame
text_frame.text = "Any questions?"
apply_text_style(text_frame, font_size=20)

# Save the presentation
prs.save("Styled_Health_Prediction_Models_Presentation_v3.pptx")
